# %%
#usando metodo csv
import csv

with open('salarios.csv', 'r') as arquivo:
    salario = csv.reader(arquivo)
    dados = list(salario)
    for linha in dados[0:6]:
        print(linha)
# Out:
# ['Name', 'Position Title', 'Department', 'Employee Annual Salary']
# ['AARON,  ELVIA J', 'WATER RATE TAKER', 'WATER MGMNT', '$88967.00']
# ['AARON,  JEFFERY M', 'POLICE OFFICER', 'POLICE', '$80778.00']
# ['AARON,  KARINA', 'POLICE OFFICER', 'POLICE', '$80778.00']
# ['AARON,  KIMBERLEI R', 'CHIEF CONTRACT EXPEDITER', 'GENERAL SERVICES', '$84780.00']
# ['ABAD JR,  VICENTE M', 'CIVIL ENGINEER IV', 'WATER MGMNT', '$104736.00']

# %%
#usando metodo pandas
import pandas as pd

file = 'salarios.csv'

df = pd.read_csv(file) #leitura do arquivo
df_salary = pd.DataFrame(df)#transforma em dataframe(tabela manipulavel)
df_salary.head().sort_values(by='Employee Annual Salary', ascending=False) #exibe
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $88967.00
# 3              $84780.00
# 1              $80778.00
# 2              $80778.00
# 4             $104736.00

# %%
max_salary = df_salary.sort_values(by='Employee Annual Salary', ascending=False)
max_salary
# Out:
#                         Name                   Position Title      Department  \
# 23527      RAPELYEA,  SEAN M              ADMINISTRATIVE ASST  MAYOR'S OFFICE
# 28348    TAYLOR,  KIMBERLY A              DEPUTY COMMISSIONER    DISABILITIES
# 28486  THEOPHILOS,  GEORGE D  ASST CORPORATION COUNSEL SUPVSR             LAW
# 2408          BOMAN,  JOAN D  ASST CORPORATION COUNSEL SUPVSR             LAW
# 22058       PAYNE,  TRACEY H  ASST CORPORATION COUNSEL SUPVSR             LAW
# ...                      ...                              ...             ...
# 13638       JILEK,  GEORGE J                          DENTIST          HEALTH
# 20999      O CONNOR,  JOSEPH                HOISTING ENGINEER      TRANSPORTN
# 1945       BERGER,  THEODORE                       DEPUTY DIR            OEMC
# 15111          KOCH,  STEVEN         ADMINISTRATIVE SECRETARY  MAYOR'S OFFICE
# 32181                    NaN                              NaN             NaN
#
#       Employee Annual Salary
# ...
